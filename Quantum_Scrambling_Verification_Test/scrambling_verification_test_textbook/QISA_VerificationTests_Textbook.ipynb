# %% [markdown]
# # Quantum Information Scrambling Analysis (QISA) Teleportation Protocol

# %% [markdown]
# ## Contents
#
# 1. [Introduction](#intro)
# 2. [What is a Quantum Scrambling?](#whatis)
# 3. [Scrambling Verification Teleportation Protocol](#teleportation)
# 4. [Example: Tunable Scrambling Circuit](#tunedscrambling)
# 5. [Example: Cases for QISA](#qisacases)
# 6. [Recources and recommended readings](#readings)
#
# ## 1. Introduction <a id='intro'></a>
#
# Lorem ipsum...
#
# ## 2. What is a Quantum Scrambling? <a id='whatis'></a>
#
# Lorem ipsum...
#
#
# ## 3. Scrambling Verification Teleportation Protocol <a id='teleportation'></a>
#
# Remember [the quantum teleportation algorithm](https://qiskit.org/textbook/ch-algorithms/teleportation.html)?
#
# Lorem ipsum...
#
#
# ### Setup and initialization of the many-body system
#
#
# Lorem ipsum...
#
#
# ### Scrambling Unitaries
#
# General description of unitary in terms of
#
# $$
# U†(X ⊗ I ⊗ I)U = X ⊗ Z ⊗ Z
# $$
#
# $$
# U†(I ⊗ X ⊗ I)U = Z ⊗ X ⊗ Z
# $$
#
# $$
# U†(I ⊗ I ⊗ X)U = Z ⊗ Z ⊗ X
# $$
#
# $$
# U†(Y ⊗ I ⊗ I)U = Y ⊗ X ⊗ X
# $$
#
# $$
# U†(I ⊗ Y ⊗ I)U = X ⊗ Y ⊗ X
# $$
#
# $$
# U†(I ⊗ I ⊗ Y )U = X ⊗ X ⊗ Y
# $$
#
# $$
# U†(Z ⊗ I ⊗ I)U = Z ⊗ Y ⊗ Y
# $$
#
# $$
# U†(I ⊗ Z ⊗ I)U = Y ⊗ Z ⊗ Y
# $$
#
# $$
# U†(I ⊗ I ⊗ Z)U = Y ⊗ Y ⊗ Z
# $$
#
# - Link to Operator Library
# - Link to Demo Verification Circuits
# - Link to Dema Verification Operator Library
#
# **Example Gate Set: Perfect Scrambling Gate Set CZ & H**
#
#
#
# ### Measurement and teleportation fidelity
#
# - Bob Gates
# - Interpretation of Teleportation Fidelity in terms of scrambling

# %% [markdown]
# ##  4. Example: Tunable Scrambling Circuit <a id='tunedscrambling'></a>
#
# Lorem ipsum...
#
# ### Tunable Scrambling Circuit
#
# Lorem ipsum...
#
# ### Tuning Parameter
#
# Lorem ipsum...
#
# $$
# \theta = \frac{\alpha \pi}{2}
# $$
#
# Lorem ipsum...
#
# ### How to tune: Examples
#
# Lorem ipsum...
#
# #### Example 1: Full Fidelity with $\alpha = 1 $
#
# Lorem ipsum...
#
# #### Example 2: Zero Fidelity with $\alpha = -1 $
#
# Lorem ipsum...
#
# #### Example 3: Fifty Percent Fidelity with $\alpha = 0 $
#
# Lorem ipsum...

# %% [markdown]
# ## 5. Example: Cases for QISA  <a id='qisacases'></a>
#
# Lorem ipsum...
#
# ### Pulses
#
# Lorem ipsum...
#
# ### Graphs
#
# Lorem ipsum...
#
# ### Random Circuits
#
# Lorem ipsum...

# %% [markdown]
# ## 6. Recources and recommended readings<a id='readings'></a>
#
# - Verified Quantum Information Scrambling [arXiv:1806.02807[quant-ph]](#Ref.1)
