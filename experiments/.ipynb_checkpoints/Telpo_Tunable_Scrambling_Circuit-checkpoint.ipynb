# %%
# %matplotlib inline
import matplotlib, qiskit, pprint
from matplotlib import pyplot as plt
import numpy as np
from numpy import pi
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, Aer, IBMQ, transpile, schedule, assemble
from qiskit.providers.aer import QasmSimulator
from qiskit.test.mock import FakeAlmaden, FakeMelbourne
# load account
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
# simulators:
f_alma = FakeAlmaden() # simulator f_alma for pulse schedules
f_mel = FakeMelbourne() # simulator f_mel for simulator backend mel
qasm_simulator = Aer.get_backend('qasm_simulator')
# Out:
# ibmqfactory.load_account:WARNING:2021-05-14 16:17:25,964: Credentials are already in use. The existing account in the session will be replaced.

# %% [markdown]
# # Tunable Scrambling Circuit
#
# Reproduce Us(α) Ud(α) Teleportation Circuit designed to probe the OTOC and teleportation fidelity as a function of the scrambling parameter α with α = 0 representing no scrambling and α = 1 representing full scrambling.
#
# Reference: Verified Quantum Information Scrambling https://arxiv.org/abs/1806.02807
#
# ![paper](.\\pics\\Telpo1_Tunable_Scrambling_Circ.jpg)
#
# ![experiment](.\\pics\\Telpo2_Tunable_Scrambling_Circ.jpg)
#
# Tunable Circ:
#
# ![tunable](.\\pics\\Telpo3_Tunable_Scrambling_Circ.jpg)

# %% [markdown]
# ## General Functions:

# %%
# funcs for bell pair entanglement and measurement

def entangle_bell_pairs(circ, bell_pairs):
    # Define many-body-system bell pairs
    for pair in bell_pairs:
        circ.h(pair[0])
        circ.cx(pair[0],pair[1])

def disentangle_bell_pair(circ, pair):
    circ.cx(pair[0], pair[1])
    circ.h(pair[0])

# %%
# func to return thet for Z rotation from Unitary parameter alpha

def get_theta_from_alpha(alpha):
    return (alpha*pi)/2

# %%
# find initial bell pairs for n qubit circ

def get_bell_pairs(circ):

    n = len(circ.qubits)
    # make pairings:
    if n%2 != 0:
        initalsys = [x for x in range(n)][1:-1] # put first and last qubits aside for initial entanglement of the system
        pairs = [[item,initalsys[int(len(initalsys)/2):][number]]
                         for (number,item) in enumerate(reversed(initalsys[:int(len(initalsys)/2)]))]
    else:
        print("Find out how to deal with even number circ, Hannah!")
    # append pair bob and q before bob:   
    pairs.append([n-2, n-1]) 
    
    return pairs

# %%
# finc to get structure of scrambling U and U* for n qubit circ

def get_unitary_pairs(circ):
    
    if n%2 != 0:
        upper_qs = [x for x in range(n-1)][:int(n/2)]
        lower_qs = [x for x in range(n-1)][int(n/2):]
    else:
        print("Find out how to deal with even number circ, Hannah!")
    
    upper_pairs = sorted([(upper_qs[i],upper_qs[i+1]) 
                   for i in range(len(upper_qs)-1)] + [(upper_qs[i],upper_qs[i+2]) 
                                                       for i in range(len(upper_qs)-2)])

    lower_pairs = sorted([(lower_qs[i],lower_qs[i+1]) 
                   for i in range(len(lower_qs)-1)] + [(lower_qs[i],lower_qs[i+2]) 
                                                       for i in range(len(lower_qs)-2)])
    
    lower_pairs = [x for x in reversed(lower_pairs)]
    
    return upper_pairs, lower_pairs

# %%
# func to apply tunable U(alpha)

def apply_tunable_srambling_unitary(circ, alpha, pairs):
     
    theta = get_theta_from_alpha(alpha)

    for pair in pairs:
        circ.rxx(-pi/4, pair[0],pair[1]) # rxx -pi/4 
    circ.barrier()
    for i in range(n-1):
        circ.rz(-theta,i)                # rz -theta 
    for pair in upper_pairs+lower_pairs:
        circ.rxx(-pi/4, pair[0],pair[1]) # rxx -pi/4 
    circ.barrier()
    for i in range(n-1):
        circ.rz(theta,i)                 # rz +theta

# %%
# func to insert bell meas

def insert_bell_measurement(circ, pair):
    circ.barrier()
    circ.cx(pair[0],pair[1])
    circ.h(pair[0])
    circ.measure(pair[0],pair[0])
    circ.measure(pair[1],pair[1])
    circ.barrier()

# %% [markdown]
# # Tests:

# %% [markdown]
# ### alpha = 0

# %%
########################### set alpha #####################################

alpha = 0
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0, 1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = f_mel
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=0: 0.0
#
#  fake_melbourne
#
#  Fidelity Bob Qubit: 	47.94%
#
#  Fidelity Bob Partner: 	7.22%
#
#  Fidelity Base Meas A: 	6.04%
#
#  Fidelity Base Meas B: 	45.98%

# %%
########################### set alpha #####################################

alpha = 0
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0, 1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = f_alma
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=0: 0.0
#
#  fake_almaden
#
#  Fidelity Bob Qubit: 	27.67%
#
#  Fidelity Bob Partner: 	2.62%
#
#  Fidelity Base Meas A: 	3.9%
#
#  Fidelity Base Meas B: 	53.47%

# %%
########################### set alpha #####################################

alpha = 0
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0, 1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = qasm_simulator
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=0: 0.0
#
#  qasm_simulator
#
#  Fidelity Bob Qubit: 	24.98%
#
#  Fidelity Bob Partner: 	0.0%
#
#  Fidelity Base Meas A: 	0.0%
#
#  Fidelity Base Meas B: 	49.92%

# %% [markdown]
# ### alpha = 0.5

# %%
########################### set alpha #####################################

alpha = 0.5
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0,1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = f_mel
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=0.5: 0.7853981633974483
#
#  fake_melbourne
#
#  Fidelity Bob Qubit: 	56.57%
#
#  Fidelity Bob Partner: 	13.74%
#
#  Fidelity Base Meas A: 	34.28%
#
#  Fidelity Base Meas B: 	51.44%

# %%
########################### set alpha #####################################

alpha = 0.5
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0,1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = f_alma
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=0.5: 0.7853981633974483
#
#  fake_almaden
#
#  Fidelity Bob Qubit: 	41.95%
#
#  Fidelity Bob Partner: 	10.02%
#
#  Fidelity Base Meas A: 	31.88%
#
#  Fidelity Base Meas B: 	58.3%

# %%
########################### set alpha #####################################

alpha = 0.5
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0,1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = qasm_simulator
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=0.5: 0.7853981633974483
#
#  qasm_simulator
#
#  Fidelity Bob Qubit: 	42.04%
#
#  Fidelity Bob Partner: 	8.44%
#
#  Fidelity Base Meas A: 	34.18%
#
#  Fidelity Base Meas B: 	56.74%

# %% [markdown]
# ### alpha = 1

# %%
########################### set alpha #####################################

alpha = 1
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0,1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = f_mel
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=1: 1.5707963267948966
#
#  fake_melbourne
#
#  Fidelity Bob Qubit: 	58.0%
#
#  Fidelity Bob Partner: 	40.38%
#
#  Fidelity Base Meas A: 	47.84%
#
#  Fidelity Base Meas B: 	45.9%

# %%
########################### set alpha #####################################

alpha = 1
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0,1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = f_alma
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=1: 1.5707963267948966
#
#  fake_almaden
#
#  Fidelity Bob Qubit: 	43.58%
#
#  Fidelity Bob Partner: 	40.88%
#
#  Fidelity Base Meas A: 	44.75%
#
#  Fidelity Base Meas B: 	54.8%

# %%
########################### set alpha #####################################

alpha = 1
print("Theta for alpha={}:".format(alpha),get_theta_from_alpha(alpha))

########################### circuit and structure #########################

# set number of qubits
n = 7

# circ 
circ = QuantumCircuit(n,n)
# structure 
bell_pairs = get_bell_pairs(circ)
upper_pairs, lower_pairs = get_unitary_pairs(circ)
# pairs for mesurements
basemeas = bell_pairs[0]
bob_pair = bell_pairs[-1]
# inums for results
meas_a_i, meas_b_i = -1 * (basemeas[0]+1), -1 * (basemeas[1]+1)
bob_imeas, bob_pmeas = 0,1

########################### apply protocol ################################

# 1. entangle EPR pairs
entangle_bell_pairs(circ, bell_pairs)
circ.barrier()

# 2. apply tunable scrambling protocol
apply_tunable_srambling_unitary(circ, alpha, upper_pairs) # U
apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U*
#apply_tunable_srambling_unitary(circ, alpha, lower_pairs) # U'

# 3. measure base EPR pair 
insert_bell_measurement(circ,basemeas)

# 4. measure Bob paair
insert_bell_measurement(circ,bob_pair)

########################### run simulation ################################

be = qasm_simulator
pct = 100
shots = 100*pct
qobj = assemble(circ, shots=shots)
result = be.run(qobj).result().get_counts()

############################ see results ##################################

bob_meas_1  = sum([v for (k,v) in result.items() if k[bob_imeas]=="1"])
bob_p_meas_1 = sum([v for (k,v) in result.items() if k[bob_pmeas]=="1"])
meas1_1 = sum([v for (k,v) in result.items() if k[meas_a_i]=="1"])
meas2_1 =  sum([v for (k,v) in result.items() if k[meas_b_i]=="1"])
print("\n",be)
print("\n Fidelity Bob Qubit: \t{}%".format(bob_meas_1/pct)) 
print("\n Fidelity Bob Partner: \t{}%".format(bob_p_meas_1/pct)) 
print("\n Fidelity Base Meas A: \t{}%".format(meas1_1/pct)) 
print("\n Fidelity Base Meas B: \t{}%".format(meas2_1/pct)) 
#pprint.pprint(result)

############################ see circuit ##################################

#circ.draw('mpl', plot_barriers=False)
# Out:
# Theta for alpha=1: 1.5707963267948966
#
#  qasm_simulator
#
#  Fidelity Bob Qubit: 	43.42%
#
#  Fidelity Bob Partner: 	43.98%
#
#  Fidelity Base Meas A: 	50.8%
#
#  Fidelity Base Meas B: 	51.33%
